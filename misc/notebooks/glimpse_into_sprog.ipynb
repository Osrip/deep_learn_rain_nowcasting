# %%
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np
from pysteps.visualization import plot_precip_field

# %%
dataset = xr.open_dataset('/Users/jan/Downloads/testdata_two_days_2019_01_01-02_sprog_predictions.zarr', engine='zarr')
dataset
# Out:
# <xarray.Dataset> Size: 72GB
# Dimensions:    (lead_time: 12, time: 572, y: 1200, x: 1100)
# Coordinates:
#   * lead_time  (lead_time) timedelta64[ns] 96B 00:00:00 00:05:00 ... 00:55:00
#     step       timedelta64[ns] 8B ...
#   * time       (time) datetime64[ns] 5kB 2019-01-01 ... 2019-01-02T23:35:00
#   * x          (x) float64 9kB -543.5 -542.5 -541.5 -540.5 ... 553.5 554.5 555.5
#   * y          (y) float64 10kB -3.61e+03 -3.611e+03 ... -4.808e+03 -4.809e+03
# Data variables:
#     sprog      (lead_time, time, y, x) float64 72GB ...

# %%
test = dataset.sprog.isel(
    time=50, #8
)
test.time
# Out:
# <xarray.DataArray 'time' ()> Size: 8B
# array('2019-01-01T04:10:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     step     timedelta64[ns] 8B ...
#     time     datetime64[ns] 8B 2019-01-01T04:10:00

# %%
for i in range(12):
    to_plot = dataset.sprog.isel(
        time=50, #8
        lead_time=i,
    )
    plot_precip_field(to_plot)
    # plt.imshow(to_plot, norm=LogNorm(), cmap='viridis')
    # plt.colorbar()
    plt.savefig(f'/Users/jan/Downloads/img{10+i+1}', dpi=200)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[70], line 2
#       1 for i in range(13):
# ----> 2     to_plot = dataset.sprog.isel(
#       3         time=50, #8
#       4         lead_time=i,
#       5     )
#       6     plot_precip_field(to_plot)
#       7     # plt.imshow(to_plot, norm=LogNorm(), cmap='viridis')
#       8     # plt.colorbar()
#
# File ~/miniforge3/envs/pysteps/lib/python3.10/site-packages/xarray/core/dataarray.py:1535, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1530     return self._from_temp_dataset(ds)
#    1532 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1533 # lists, or zero or one-dimensional np.ndarray's
# -> 1535 variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1536 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    1538 coords = {}
#
# File ~/miniforge3/envs/pysteps/lib/python3.10/site-packages/xarray/core/variable.py:1038, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1035 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1037 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1038 return self[key]
#
# File ~/miniforge3/envs/pysteps/lib/python3.10/site-packages/xarray/core/variable.py:805, in Variable.__getitem__(self, key)
#     802 dims, indexer, new_order = self._broadcast_indexes(key)
#     803 indexable = as_indexable(self._data)
# --> 805 data = indexing.apply_indexer(indexable, indexer)
#     807 if new_order:
#     808     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File ~/miniforge3/envs/pysteps/lib/python3.10/site-packages/xarray/core/indexing.py:1030, in apply_indexer(indexable, indexer)
#    1028     return indexable.oindex[indexer]
#    1029 else:
# -> 1030     return indexable[indexer]
#
# File ~/miniforge3/envs/pysteps/lib/python3.10/site-packages/xarray/core/indexing.py:848, in MemoryCachedArray.__getitem__(self, indexer)
#     846 def __getitem__(self, indexer: ExplicitIndexer):
#     847     self._check_and_raise_if_non_basic_indexer(indexer)
# --> 848     return type(self)(_wrap_numpy_scalars(self.array[indexer]))
#
# File ~/miniforge3/envs/pysteps/lib/python3.10/site-packages/xarray/core/indexing.py:798, in CopyOnWriteArray.__getitem__(self, indexer)
#     796 def __getitem__(self, indexer: ExplicitIndexer):
#     797     self._check_and_raise_if_non_basic_indexer(indexer)
# --> 798     return type(self)(_wrap_numpy_scalars(self.array[indexer]))
#
# File ~/miniforge3/envs/pysteps/lib/python3.10/site-packages/xarray/core/indexing.py:673, in LazilyIndexedArray.__getitem__(self, indexer)
#     671 def __getitem__(self, indexer: ExplicitIndexer):
#     672     self._check_and_raise_if_non_basic_indexer(indexer)
# --> 673     return type(self)(self.array, self._updated_key(indexer))
#
# File ~/miniforge3/envs/pysteps/lib/python3.10/site-packages/xarray/core/indexing.py:634, in LazilyIndexedArray._updated_key(self, new_key)
#     632         full_key.append(k)
#     633     else:
# --> 634         full_key.append(_index_indexer_1d(k, next(iter_new_key), size))
#     635 full_key_tuple = tuple(full_key)
#     637 if all(isinstance(k, integer_types + (slice,)) for k in full_key_tuple):
#
# File ~/miniforge3/envs/pysteps/lib/python3.10/site-packages/xarray/core/indexing.py:307, in _index_indexer_1d(old_indexer, applied_indexer, size)
#     305     indexer = slice_slice(old_indexer, applied_indexer, size)
#     306 elif isinstance(applied_indexer, integer_types):
# --> 307     indexer = range(*old_indexer.indices(size))[applied_indexer]  # type: ignore[assignment]
#     308 else:
#     309     indexer = _expand_slice(old_indexer, size)[applied_indexer]
#
# IndexError: range object index out of range

# %%
load_path = '/Users/jan/Programming/first_CNN_on_Radolan/dwd_nc/own_test_data/testdata_two_days_2019_01_01-02.zarr'
observed_data = xr.open_dataset(load_path, engine='zarr')
observed_data.dims
# Out:
# FrozenMappingWarningOnValuesAccess({'step': 1, 'time': 576, 'y': 1200, 'x': 1100})

# %%
observed_plotting = observed_data.RV_recalc.sel(
    time='2019-01-01T04:30:00.000000000', #8
)
observed_plotting.time
# Out:
# <xarray.DataArray 'time' ()> Size: 8B
# array('2019-01-01T04:30:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 2019-01-01T04:30:00

# %%
observed_plotting = np.squeeze(observed_plotting.values)


# plt.imshow(observed_plotting, norm=LogNorm(), cmap='viridis')
# plt.colorbar()
plot_precip_field(observed_plotting)
plt.savefig(f'/Users/jan/Downloads/img_10.png', dpi=200)
plt.show()

# %%
dataset.time[50]
# Out:
# <xarray.DataArray 'time' ()> Size: 8B
# array('2019-01-01T04:10:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     step     timedelta64[ns] 8B ...
#     time     datetime64[ns] 8B 2019-01-01T04:10:00

# %%
observed_data.time[50]
# Out:
# <xarray.DataArray 'time' ()> Size: 8B
# array('2019-01-01T04:10:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 8B 2019-01-01T04:10:00

# %%
observed_data.attrs
# Out:
# {'crs': '+proj=stere +lat_0=90 +lat_ts=90 +lon_0=10 +k=0.93301270189 +x_0=0 +y_0=0 +a=6370040 +b=6370040 +to_meter=1000 +no_defs',
#  'nodata': nan,
#  'notes': 'The grid point RV_recalc[0,0] corresponds to the top-left corner. Transform root point is top-left. Grid coordinates indicate the bottom left corner of the pixel. The data values were interpolated if the time values of the dataset did not match the desired time values.',
#  'transform': [1.0, 0.0, -543.4621669218559, 0.0, -1.0, -3609.644724265573]}

# %%
load_path_dem = '/Users/jan/Programming/geo_data/static/dem_benchmark_dataset_1200_1100.zarr'
dem = xr.open_zarr(load_path_dem)

# %%
dem.attrs
# Out:
# {'crs': '+proj=stere +lat_0=90 +lat_ts=90 +lon_0=10 +k=0.93301270189 +x_0=0 +y_0=0 +a=6370040 +b=6370040 +to_meter=1000 +no_defs',
#  'nodata': nan,
#  'transform': [1.0,
#   0.0,
#   -543.4621669218559,
#   0.0,
#   -1.0,
#   -3609.644724265573,
#   0.0,
#   0.0,
#   1.0]}

# %%
plt.imshow()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 plt.imshow()
#
# TypeError: imshow() missing 1 required positional argument: 'X'
